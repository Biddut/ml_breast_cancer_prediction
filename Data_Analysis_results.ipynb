# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df = df.drop(['id','Unnamed: 32'],axis = 1)
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
#df.shape
print('No of missing values:')
for col in df.columns:
    print('\t%s: %d' % (col,df[col].isna().sum()))
# Out:
# No of missing values:
# 	diagnosis: 0
# 	radius_mean: 0
# 	texture_mean: 0
# 	perimeter_mean: 0
# 	area_mean: 0
# 	smoothness_mean: 0
# 	compactness_mean: 0
# 	concavity_mean: 0
# 	concave points_mean: 0
# 	symmetry_mean: 0
# 	fractal_dimension_mean: 0
# 	radius_se: 0
# 	texture_se: 0
# 	perimeter_se: 0
# 	area_se: 0
# 	smoothness_se: 0
# 	compactness_se: 0
# 	concavity_se: 0
# 	concave points_se: 0
# 	symmetry_se: 0
# 	fractal_dimension_se: 0
# 	radius_worst: 0
# 	texture_worst: 0
# 	perimeter_worst: 0
# 	area_worst: 0
# 	smoothness_worst: 0
# 	compactness_worst: 0
# 	concavity_worst: 0
# 	concave points_worst: 0
# 	symmetry_worst: 0
# 	fractal_dimension_worst: 0

# %%
#df.diagnosis.unique()
print('No of Each Class: ')
print(df['diagnosis'].value_counts())
# Out:
# No of Each Class:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
import warnings
warnings.filterwarnings("ignore")
sns.countplot(df['diagnosis'], palette='husl')
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %%
columns_list_mean=['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']

# %%
for col_name in columns_list_mean:
  #m = plt.hist(df[df["diagnosis"] == "M"].get(col_name),bins=30,fc = (1,0,0,0.5),label = "Malignant")
  #b = plt.hist(df[df["diagnosis"] == "B"].get(col_name),bins=30,fc = (0,1,0,0.5),label = "Benign")
  x=plt.hist(df[col_name],bins=30,fc = (0,1,0,0.5),label = "Breast Cancer")
  plt.legend()
  plt.xlabel("%s values"%col_name)
  plt.ylabel("Frequency")
  plt.title("Histogram of %s for Benign and Malignant Tumors" %col_name)
  plt.show()

# %%
#Insert your code here
for col_name in columns_list_mean:
  m = plt.hist(df[df["diagnosis"] == "M"].get(col_name),bins=30,fc = (1,0,0,0.5),label = "Malignant")
  b = plt.hist(df[df["diagnosis"] == "B"].get(col_name),bins=30,fc = (0,1,0,0.5),label = "Benign")
  plt.legend()
  plt.xlabel("%s values"%col_name)
  plt.ylabel("Frequency")
  plt.title("Histogram of %s for Benign and Malignant Tumors" %col_name)
  plt.show()
  print("Most frequent malignant %s is: %0.3f"%(col_name,m[1][list(m[0]).index(m[0].max())]))
  print("Most frequent Benign %s is: %0.3f"%(col_name,b[1][list(b[0]).index(b[0].max())]))
# Out:
# Most frequent malignant radius_mean is: 20.102
# Most frequent Benign radius_mean is: 11.329
# Most frequent malignant texture_mean is: 20.977
# Most frequent Benign texture_mean is: 16.940
# Most frequent malignant perimeter_mean is: 106.880
# Most frequent Benign perimeter_mean is: 76.835
# Most frequent malignant area_mean is: 646.853
# Most frequent Benign area_mean is: 398.080
# Most frequent malignant smoothness_mean is: 0.097
# Most frequent Benign smoothness_mean is: 0.086
# Most frequent malignant compactness_mean is: 0.126
# Most frequent Benign compactness_mean is: 0.074
# Most frequent malignant concavity_mean is: 0.145
# Most frequent Benign concavity_mean is: 0.014
# Most frequent malignant concave points_mean is: 0.087
# Most frequent Benign concave points_mean is: 0.017
# Most frequent malignant symmetry_mean is: 0.177
# Most frequent Benign symmetry_mean is: 0.162
# Most frequent malignant fractal_dimension_mean is: 0.061
# ...

# %% [markdown]
#    **From the histogram analysis we see that Malignant tumors are significantly  larger( longer range) in the features that has "_means" .**

# %%
# %matplotlib inline
df.boxplot(figsize=(20,12),column=['concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean'])
# Out:
# <AxesSubplot:>

# %%
for col_name in ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean']:
  melted_data = pd.melt(df,id_vars = "diagnosis",value_vars = [col_name])
  plt.figure(figsize = (6,4))
  sns.boxplot(x = "variable", y = "value", hue="diagnosis",data= melted_data)
plt.show()

# %% [markdown]
# * The boxplots suggest that all of four features columns contain outlier.
# * The median value of various variables is much higher in Malignant cases.

# %%
cols = ['diagnosis','radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean','compactness_mean', 'concavity_mean','concave points_mean','symmetry_mean', 'fractal_dimension_mean']
#sns.pairplot(data=df[cols], hue='diagnosis',kind="kde", palette='rocket')
sns.pairplot(data=df[cols], hue='diagnosis',corner=True, palette='rocket')

# %%
Answers : 

1. There are  patterns between the radius, perimeter and area mean features suggest that they are highly linearly related
2. Another set of variables that possibly have multicollinearity are the concavity, concave_points and compactness

Finding highly related features  is important as multicollinearity undermines significance of independent varibales.

# %% [markdown]
# To remove the highly correlated predictors from the model Use Partial Least Squares Regression (PLS) or Principal Components Analysis, regression methods that cut the number of predictors to a smaller set of uncorrelated components.

# %%
corr = df.corr().round(2)

# Mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set figure size
f, ax = plt.subplots(figsize=(20, 20))

# Define custom colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

plt.tight_layout()

# %%
# first, drop all "worst" columns
cols = ['radius_worst', 
        'texture_worst', 
        'perimeter_worst', 
        'area_worst', 
        'smoothness_worst', 
        'compactness_worst', 
        'concavity_worst',
        'concave points_worst', 
        'symmetry_worst', 
        'fractal_dimension_worst']
df = df.drop(cols, axis=1)

# then, drop all columns related to the "perimeter" and "area" attributes
cols = ['perimeter_mean',
        'perimeter_se', 
        'area_mean', 
        'area_se']
df = df.drop(cols, axis=1)

# lastly, drop all columns related to the "concavity" and "concave points" attributes
cols = ['concavity_mean',
        'concavity_se', 
        'concave points_mean', 
        'concave points_se']
df = df.drop(cols, axis=1)

# verify remaining columns
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'smoothness_mean',
#        'compactness_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'smoothness_se', 'compactness_se',
#        'symmetry_se', 'fractal_dimension_se'],
#       dtype='object')

# %%
# Draw the heatmap again, with the new correlation matrix
corr = df.corr().round(2)
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
plt.tight_layout()

# %% [markdown]
# ## Building Model

# %%
X=df.drop(['diagnosis'],axis=1)
y = df['diagnosis']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=40)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

X_train=ss.fit_transform(X_train)
X_test=ss.fit_transform(X_test)

# %% [markdown]
# ## Models and finding out the Best one¶
# #### 1.Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

model1=lr.fit(X_train,y_train)
prediction1=model1.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,prediction1)
cm
# Out:
# array([[110,   5],
#        [  2,  54]], dtype=int64)

# %%
sns.heatmap(cm,annot=True)
plt.savefig('h.png')

# %%
TP=cm[0][0]
TN=cm[1][1]
FN=cm[1][0]
FP=cm[0][1]
print('Testing Accuracy:',(TP+TN)/(TP+TN+FN+FP))
# Out:
# Testing Accuracy: 0.9590643274853801

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test,prediction1)
# Out:
# 0.9590643274853801

# %% [markdown]
# ##### 2.Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
model2=dtc.fit(X_train,y_train)
prediction2=model2.predict(X_test)
cm2= confusion_matrix(y_test,prediction2)
cm2
# Out:
# array([[106,   9],
#        [  8,  48]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test,prediction2)
# Out:
# 0.9005847953216374

# %% [markdown]
# ##### 3.Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier()
model3 = rfc.fit(X_train, y_train)
prediction3 = model3.predict(X_test)
confusion_matrix(y_test, prediction3)
# Out:
# array([[106,   9],
#        [  4,  52]], dtype=int64)

# %%
accuracy_score(y_test,prediction3)
# Out:
# 0.9239766081871345

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, prediction1))
print(classification_report(y_test, prediction2))
print(classification_report(y_test, prediction3))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.98      0.96      0.97       115
#            M       0.92      0.96      0.94        56
#
#     accuracy                           0.96       171
#    macro avg       0.95      0.96      0.95       171
# weighted avg       0.96      0.96      0.96       171
#
#               precision    recall  f1-score   support
#
#            B       0.93      0.92      0.93       115
#            M       0.84      0.86      0.85        56
#
#     accuracy                           0.90       171
#    macro avg       0.89      0.89      0.89       171
# weighted avg       0.90      0.90      0.90       171
#
#               precision    recall  f1-score   support
#
#            B       0.96      0.92      0.94       115
#            M       0.85      0.93      0.89        56
#
#     accuracy                           0.92       171
#    macro avg       0.91      0.93      0.92       171
# ...

# %% [markdown]
# #### K Nearest Neighbor (K NN)¶
# #### Support Vector Machine
# #### Naive Bayes

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# %%
models=[]

models.append(('KNN', KNeighborsClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))

# %%
models
# Out:
# [('KNN', KNeighborsClassifier()), ('NB', GaussianNB()), ('SVM', SVC())]

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
# evaluate each model
results =[]
names=[]
for name , model in models:
    kfold=KFold(n_splits=10, random_state=40)
    cv_results= cross_val_score(model, X_train, y_train, cv=kfold,scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    
    msg= '%s:, %f, (%f)' % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# KNN:, 0.909551, (0.040622)
# NB:, 0.902115, (0.032342)
# SVM:, 0.927308, (0.037677)

# %%
# make predictions on validation datasets

SVM = SVC()
SVM.fit(X_train, y_train)
predictions= SVM.predict(X_test)
print(accuracy_score(y_test, predictions))
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
# 0.9649122807017544
#               precision    recall  f1-score   support
#
#            B       0.97      0.97      0.97       115
#            M       0.95      0.95      0.95        56
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.96      0.96       171
# weighted avg       0.96      0.96      0.96       171
#
# [[112   3]
#  [  3  53]]

# %% [markdown]
# ## We are getting the best accuracy with SVM which is 96.4% , the model is predicting with 96% accuracy on our test data
